# %% [markdown]
# # Laboratório 03 — Análise Exploratória e Visualização
#
# **Base:** Palmer Penguins
# **Tempo estimado:** 60–80 minutos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 1. Diagnóstico inicial

# %%
print(df.shape)
display(df.info())
display(df.isna().sum())
# Out:
# (344, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
dados = df.dropna().copy()
dados.describe(include="all").T
# Out:
#                    count unique     top freq         mean         std     min  \
# species              333      3  Adelie  146          NaN         NaN     NaN
# island               333      3  Biscoe  163          NaN         NaN     NaN
# bill_length_mm     333.0    NaN     NaN  NaN    43.992793    5.468668    32.1
# bill_depth_mm      333.0    NaN     NaN  NaN    17.164865    1.969235    13.1
# flipper_length_mm  333.0    NaN     NaN  NaN   200.966967   14.015765   172.0
# body_mass_g        333.0    NaN     NaN  NaN  4207.057057  805.215802  2700.0
# sex                  333      2    Male  168          NaN         NaN     NaN
#
#                       25%     50%     75%     max
# species               NaN     NaN     NaN     NaN
# island                NaN     NaN     NaN     NaN
# bill_length_mm       39.5    44.5    48.6    59.6
# bill_depth_mm        15.6    17.3    18.7    21.5
# flipper_length_mm   190.0   197.0   213.0   231.0
# body_mass_g        3550.0  4050.0  4775.0  6300.0
# sex                   NaN     NaN     NaN     NaN

# %% [markdown]
# ## 2. Distribuição univariada

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=dados, x="flipper_length_mm", hue="species", kde=True)
plt.title("Distribuição do comprimento da nadadeira")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# -

# %% [markdown]
# ## 3. Identificação de valores extremos

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=dados, x="species", y="body_mass_g")
plt.title("Massa corporal por espécie")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# -

# %% [markdown]
# ## 4. Relação entre variáveis

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=dados,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    style="sex"
)
plt.title("Comprimento e profundidade do bico")
plt.show()

# %% [markdown]
# **Interpretação:**
#
# -

# %% [markdown]
# ## 5. Correlação

# %%
numericas = dados.select_dtypes(include="number")
correlacao = numericas.corr()

plt.figure(figsize=(7, 5))
sns.heatmap(correlacao, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Matriz de correlação")
plt.show()

# %% [markdown]
# ### Atividade
# Responda:
# 1. Quais variáveis apresentam maior correlação?
# 2. Há separação visual entre as espécies?
# 3. Qual gráfico foi mais útil para compreender os dados? Por quê?

# %% [markdown]
# **Resposta:**
#
# 1. flipper_length_mm e body_mass_g
# 2. xxx
# 3. xxx

# %% [markdown]
# ## 6. Produção autoral

# %%
# Crie abaixo uma quinta visualização escolhida por você.
# Ela deve responder a uma pergunta claramente formulada.

pergunta = "Escreva aqui a pergunta da sua análise"
print(pergunta)

# Seu gráfico:
# Out:
# Escreva aqui a pergunta da sua análise

# %% [markdown]
# ## Entrega
# Salve como `LAB03_NomeSobrenome.ipynb` com interpretações para todos os gráficos.
