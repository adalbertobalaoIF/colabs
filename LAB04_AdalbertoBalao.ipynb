# %% [markdown]
# # Laboratório 04 — Distâncias e Similaridades
#
# **Base:** Wine
# **Tempo estimado:** 60–75 minutos

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy.spatial.distance import euclidean, cityblock, cosine

wine = load_wine(as_frame=True)
df = wine.frame.copy()
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %% [markdown]
# ## 1. Seleção de observações

# %%
atributos = ["alcohol", "malic_acid", "color_intensity", "proline"]
amostra = df.loc[[0, 1, 50], atributos]
amostra
# Out:
#     alcohol  malic_acid  color_intensity  proline
# 0     14.23        1.71             5.64   1065.0
# 1     13.20        1.78             4.38   1050.0
# 50    13.05        1.73             7.20   1150.0

# %% [markdown]
# ## 2. Distâncias sem escalonamento

# %%
a = amostra.iloc[0].to_numpy()
b = amostra.iloc[1].to_numpy()

resultados_brutos = {
    "Euclidiana": euclidean(a, b),
    "Manhattan": cityblock(a, b),
    "Cosseno (distância)": cosine(a, b)
}
resultados_brutos
# Out:
# {'Euclidiana': 15.08818743255796,
#  'Manhattan': np.float64(17.36),
#  'Cosseno (distância)': np.float64(9.478973135301771e-07)}

# %% [markdown]
# ## 3. Padronização

# %%
scaler = StandardScaler()
df_pad = pd.DataFrame(
    scaler.fit_transform(df[atributos]),
    columns=atributos,
    index=df.index
)

a_pad = df_pad.loc[0].to_numpy()
b_pad = df_pad.loc[1].to_numpy()

resultados_padronizados = {
    "Euclidiana": euclidean(a_pad, b_pad),
    "Manhattan": cityblock(a_pad, b_pad),
    "Cosseno (distância)": cosine(a_pad, b_pad)
}
resultados_padronizados
# Out:
# {'Euclidiana': 1.3863990602517482,
#  'Manhattan': np.float64(1.927964918776801),
#  'Cosseno (distância)': np.float64(0.2978625549864393)}

# %% [markdown]
# ## 4. Comparação

# %%
comparacao = pd.DataFrame({
    "Sem escalonamento": resultados_brutos,
    "Após padronização": resultados_padronizados
})
comparacao
# Out:
#                      Sem escalonamento  Após padronização
# Euclidiana                1.508819e+01           1.386399
# Manhattan                 1.736000e+01           1.927965
# Cosseno (distância)       9.478973e-07           0.297863

# %% [markdown]
# ### Atividade 1
# Explique por que a variável `proline` pode dominar a distância antes do escalonamento.

# %% [markdown]
# **Resposta:**
#
# -

# %% [markdown]
# ## 5. Vizinho mais próximo

# %%
referencia = 0

distancias = df_pad.apply(
    lambda linha: euclidean(df_pad.loc[referencia], linha),
    axis=1
).sort_values()

distancias.head(6)
# Out:
# 0     0.000000
# 48    0.402688
# 56    0.440705
# 42    0.480007
# 29    0.492422
# 47    0.520951
# dtype: float64

# %% [markdown]
# ### Atividade 2
# Ignore a distância zero do próprio registro. Identifique os cinco registros mais próximos e verifique se pertencem à mesma classe.

# %%
vizinhos = distancias.iloc[1:6].index
df.loc[vizinhos, atributos + ["target"]]
# Out:
#     alcohol  malic_acid  color_intensity  proline  target
# 48    14.10        2.02             6.20   1060.0       0
# 56    14.22        1.70             6.38    970.0       0
# 42    13.88        1.89             5.43   1095.0       0
# 29    14.02        1.68             4.70   1035.0       0
# 47    13.90        1.68             6.10    985.0       0

# %% [markdown]
# **Conclusão:**
#
# -

# %% [markdown]
# ## Entrega
# Salve como `LAB04_NomeSobrenome.ipynb`.
